# %% [markdown]
# # dewatermark quickstart
# Inspect first, then apply the least destructive cleanup. This notebook runs entirely offline.

# %%
# %pip install dewatermark

# %%
import dewatermark

text = "This\u200b looks normal."
dewatermark.analyze(text)

# %%
cleaned = dewatermark.sanitize(text)
cleaned
